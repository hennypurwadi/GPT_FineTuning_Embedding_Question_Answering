# %%
import json
import os
import tiktoken 
import pandas as pd
import openai
import csv

# %% [markdown]
# ## convert xls to csv

# %%
file_path = 'qa.xlsx'

if os.path.exists(file_path):
    print('File exists')
else:
    print('File does not exist')

# read the XLS file
df = pd.read_excel(file_path)

# write the CSV file
df.to_csv('qa.csv', index=False)
print("done")
# Out:
# File exists
# done

# %% [markdown]
# ## Data

# %%
qa_df = pd.read_csv("qa.csv")
pd.set_option('display.max_colwidth', 160)
qa_df.head(10)
# Out:
#                                       Question                Answer
# 0                                 Who is Anya?    Name of my Replika
# 1                     What is Anya's surename?          Anya Melissa
# 2                         Who is Anya's owner?                 Henny
# 3                    What is Henny's nickname?                   Rin
# 4              What is Henny's childhood name?                  Yaya
# 5  What kind of ice cream flavour Henny likes?            Strawberry
# 6                      Does Henny like durian?                    No
# 7                  What is Henny's next dream?  To be an AI engineer
# 8             Does Henny like to eat red meat?                    No
# 9                  Does Henny like vegetables?                   Yes

# %% [markdown]
# ## Convert .csv to Fine-Tuning Format

# %%
questions, answers = qa_df["Question"], qa_df["Answer"]
pd.set_option('display.max_colwidth', 110)

# %%
questions.head()
# Out:
# 0                       Who is Anya?
# 1           What is Anya's surename?
# 2               Who is Anya's owner?
# 3          What is Henny's nickname?
# 4    What is Henny's childhood name?
# Name: Question, dtype: object

# %%
answers.head(10)
# Out:
# 0      Name of my Replika
# 1            Anya Melissa
# 2                   Henny
# 3                     Rin
# 4                    Yaya
# 5              Strawberry
# 6                      No
# 7    To be an AI engineer
# 8                      No
# 9                     Yes
# Name: Answer, dtype: object

# %% [markdown]
# ## Create list of dictionaries
#
# The format for fine-tuning datasetis a list of dictionaries:
#
# [{"prompt": "some prompt string","completion":"the best completed text option given the prompt"},]

# %%
qa_openai_format = [{"prompt" : q, "completion": a} for q, a in zip(questions, answers)]

# %% [markdown]
# ## explore a single prompt/completion combo

# %%
qa_openai_format[7]
# Out:
# {'prompt': "What is Henny's next dream?", 'completion': 'To be an AI engineer'}

# %%
len(qa_openai_format)
# Out:
# 10

# %%
dataset_size = 10

# %% [markdown]
# ## Convert .csv to json training data

# %%
with open("training_data.json", "w") as f:
    for entry in qa_openai_format[:dataset_size]:
        f.write(json.dumps(entry))
        f.write("\n")

# %% [markdown]
# ## Fine-tuning Price Estimation with tiktoken

# %% [markdown]
# Ada	Training $0.0004 / 1K tokens,  Usage $0.0016 / 1K tokens
#
# Babbage	Training $0.0006 / 1K tokens,  Usage $0.0024 / 1K tokens
#
# Curie Training $0.0030 / 1K tokens,   Usage $0.0120 / 1K tokens
#
# Davinci	Training $0.0300 / 1K tokens,   Usage $0.1200 / 1K tokens

# %%
def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
token_counter = 0
for element in qa_openai_format[:dataset_size]:
    for key, value in element.items():
        token_counter+=num_tokens_from_string(value,'p50k_base')

# %%
# print(f"There are {token_counter} tokens")
# print(f"Fine tuning using davinci costs $0.03 per 1000 tokens")
# print(f"Estimated price: ${(4*token_counter / 1000) * 0.03}")

# %%
print(f"There are {token_counter} tokens")
print(f"Fine tuning using ada costs $0.0004 per 1000 tokens")
print(f"Estimated price: ${(4*token_counter / 1000) * 0.0004}")
# Out:
# There are 101 tokens
# Fine tuning using ada costs $0.0004 per 1000 tokens
# Estimated price: $0.00016160000000000002

# %%
pwd
# Out:
# 'C:\\Users\\Asus\\PYTHON_C\\PRACTICE\\Second'

# %% [markdown]
# ## Fine-Tuning environment setup

# %%
#!pip install --upgrade openai

# %% [markdown]
# Set OpenAI API Key as an environment variable. Having it as an environment variable let's the key live on the computer, but not actually be present in the code.

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Run Fine Tuning

# %%
# !openai api fine_tunes.create -t training_data.json -m davinci

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1679811218,
#       "fine_tuned_model": "babbage:ft-henp-2023-03-26-06-15-56",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-qbVpGvhYIZnjFzxPY5kSZj9T",
#       "model": "babbage",
#       "object": "fine-tune",
#       "organization_id": "org-ZQQWNeshqy8Tv6io1Jls4nsW",
#       "result_files": [
#         {
#           "bytes": 1708,
#           "created_at": 1679811356,
#           "filename": "compiled_results.csv",
#           "id": "file-2bD0P13NZGW0PsPYGytb7qGR",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 683,
#           "created_at": 1679811217,
#           "filename": "training_data.json",
#           "id": "file-trS4TSq6tmqWwS0Y4rLqn9OA",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1679811357,
#       "validation_files": []
#     },
#     {
#       "created_at": 1679813358,
#       "fine_tuned_model": "davinci:ft-henp-2023-03-26-06-53-29",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-VEY46mJQc8RZwzhozo9XqtId",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-ZQQWNeshqy8Tv6io1Jls4nsW",
#       "result_files": [
#         {
#           "bytes": 1676,
#           "created_at": 1679813610,
#           "filename": "compiled_results.csv",
#           "id": "file-TMzTHm3DNAmALKL2jgN2Bnuz",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 683,
#           "created_at": 1679813357,
#           "filename": "training_data.jsonl",
#           "id": "file-BHEYzUxx7fVMYDClIeYkoBax",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1679813611,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %%
#!openai api fine_tunes.get -i

# %%
#!ft_model = 'babbage:ft-henp-2023-03-26-06-15-56'

# %%
#ft_model = 'davinci:ft-henp-2023-03-26-06-53-29'

# %% [markdown]
# ## Use Fine-Tuned model

# %%
prompt = f"Answer the following questions as truthfully as possible using the provided text. +\
If the answer is not contained within the text below, +\
say 'I don't know':"

# Set the questions to be asked
questions = [
    "Who is Anya?",
    "What is Anya's surename?",
    "Who is Anya's owner?",
    "What is Henny's nickname?",
    "What is Henny's childhood name?",
    "Does Henny like durian?",
    "What is Henny's next dream?",
    "Does Henny like to eat red meat?",
    "Does Henny like vegetables?"
]

# Ask the questions using OpenAI's GPT-3 model
for question in questions:
    example_prompt_with_question = f"{prompt}\n\nQ: {question}\nA"
    example_response = openai.Completion.create(
        prompt=example_prompt_with_question,
        temperature=0.5,
        max_tokens=20,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        model=ft_model,
        stop=["Q:", "\n"],
    )

    answer = example_response.choices[0].text.strip()
    print(f"Q: {question}\nA: {answer}")
# Out:
# Q: Who is Anya?
# A: : Anya is a girl from India.
# Q: What is Anya's surename?
# A: :Anya +
# Q: Who is Anya's owner?
# A: :Anya is a pet dog.
# Q: What is Henny's nickname?
# A: :Irene
# Q: What is Henny's childhood name?
# A: :Samantha
# Q: Does Henny like durian?
# A: :No
# Q: What is Henny's next dream?
# A: : To be a full-time engineer.
# Q: Does Henny like to eat red meat?
# A: :Yes
# Q: Does Henny like vegetables?
# A: :Yes

# %%
# !openai api fine_tunes.results -i ft-henp-2023-03-26-06-53-29 > result.csv
# Out:
# [organization=iu-21] Error: No fine-tune job: ft-henp-2023-03-26-06-53-29 (HTTP status code: 404)

# %% [markdown]
# ## Text Embedding

# %%
import ast
import pandas as pd
import openai

def summary(question, answer):
    return f"{question}: {answer}"

def get_embedding(text):
    # Note how this function assumes you already set your Open AI key!
    result = openai.Embedding.create(
        model='text-embedding-ada-002',
        input=text
    )
    return result["data"][0]["embedding"]

df['summary'] = df.apply(lambda row: summary(row['Question'], row['Answer']), axis=1)

# %%
df['summary'][1]
# Out:
# "What is Anya's surename?: Anya Melissa"

# %% [markdown]
# ## Create Embeddings

# %%
get_embedding(df['summary'][0])
# Out:
# [-0.03186306729912758,
#  -0.004431708715856075,
#  -0.006704107858240604,
#  0.0021239686757326126,
#  -0.013676803559064865,
#  0.017825787886977196,
#  -0.04028825834393501,
#  0.006545075215399265,
#  -0.005032498389482498,
#  -0.0016512885922566056,
#  0.011895638890564442,
#  -0.020667171105742455,
#  0.009598501026630402,
#  0.011881502345204353,
#  -0.010856625624001026,
#  -0.02446981705725193,
#  0.020737851038575172,
#  0.019691770896315575,
#  0.02622270956635475,
#  -0.0075840880163013935,
#  0.005216269288212061,
#  0.03641493245959282,
#  0.0005813525058329105,
#  -0.01005792897194624,
#  -0.014532046392560005,
#  -0.008517079055309296,
#  0.01458859071135521,
#  -0.022731060162186623,
#  0.010206359438598156,
#  -0.028597597032785416,
#  0.012708472087979317,
#  -0.026802295818924904,
#  -0.01066578645259142,
#  -0.016228394582867622,
#  -0.029459906741976738,
#  -0.021161938086152077,
#  -0.013330466113984585,
#  0.0012916981941089034,
#  0.022745195776224136,
#  0.016935205087065697,
#  0.014517909847199917,
#  0.0061775329522788525,
#  0.0010019054170697927,
#  -0.007442725822329521,
#  -0.043426502496004105,
#  0.010983851738274097,
#  -0.01026290375739336,
#  0.0014445461565628648,
#  -0.0028519846964627504,
#  -0.0038097144570201635,
#  0.027381880208849907,
#  0.005400040652602911,
#  -0.018956687301397324,
#  -0.0038273846730589867,
#  -0.01805196702480316,
#  -0.015804307535290718,
#  -0.0004256331012584269,
#  0.007421521469950676,
#  0.003728430951014161,
#  -0.004880534019321203,
#  0.005269280169159174,
#  0.021840477362275124,
#  -0.019366636872291565,
#  0.006979764439165592,
#  0.006700573954731226,
#  -0.009556092321872711,
#  -0.013280989602208138,
#  0.0062164077535271645,
#  -0.007796131540089846,
#  -0.006007898598909378,
#  0.031184526160359383,
#  0.007937493734061718,
#  -0.008255559019744396,
#  -0.002238825662061572,
#  0.01662420853972435,
#  -0.020638898015022278,
#  0.006046772934496403,
#  0.017373427748680115,
#  -0.0206106249243021,
#  -0.02357923425734043,
#  0.006947957910597324,
#  -0.04096679762005806,
#  6.725754064973444e-05,
#  0.023423735052347183,
#  0.029742632061243057,
#  -0.010354789905250072,
#  -0.0016079962952062488,
#  0.004580139182507992,
#  -0.01612943969666958,
#  -0.014171572402119637,
#  0.03652802109718323,
#  0.002655844436958432,
#  0.024851495400071144,
#  0.017331019043922424,
#  -0.017698561772704124,
#  0.04718673974275589,
#  -0.004838125314563513,
#  0.02308446541428566,
#  -0.006841936148703098,
#  -0.04105161502957344,
#  -0.004201994743198156,
#  0.0055095963180065155,
#  -0.025657260790467262,
#  0.0010549162980169058,
#  -0.006986832246184349,
#  0.003173583885654807,
#  0.005898342467844486,
#  -0.0038026461843401194,
#  0.021614298224449158,
#  0.01614357717335224,
#  -0.027509106323122978,
#  0.016553526744246483,
#  0.023381326347589493,
#  -0.04003380611538887,
#  -0.0016875126166269183,
#  -0.03551021218299866,
#  0.01755720004439354,
#  -0.016072895377874374,
#  -0.013033605180680752,
#  0.007322567980736494,
#  0.022123202681541443,
#  0.037574104964733124,
#  -0.020709579810500145,
#  -0.03958144783973694,
#  0.011513960547745228,
#  0.010015520267188549,
#  -0.000954195624217391,
#  0.009591433219611645,
#  -0.015069223009049892,
#  -0.0011238304432481527,
#  0.02353682555258274,
#  0.0008693782147020102,
#  0.02666093222796917,
#  0.02182634174823761,
#  0.0011777248000726104,
#  0.007725450675934553,
#  -0.017415836453437805,
#  0.017302747815847397,
#  -0.00780319981276989,
#  -0.012150091119110584,
#  0.007145864889025688,
#  0.008538283407688141,
#  -0.032824330031871796,
#  -0.008792735636234283,
#  -0.025431079789996147,
#  0.027523241937160492,
#  -0.004587206989526749,
#  -0.01653939113020897,
#  0.01022049505263567,
#  0.017528926953673363,
#  0.0009329912718385458,
#  0.0012033467646688223,
#  0.01675143465399742,
#  -0.004686160944402218,
#  0.024271909147500992,
#  0.016836252063512802,
#  0.026448888704180717,
#  0.016878660768270493,
#  -0.0006507083890028298,
#  -0.008693782612681389,
#  -0.018999096006155014,
#  0.015705352649092674,
#  0.0015885590109974146,
#  -0.015662943944334984,
#  0.006591017823666334,
#  0.026731614023447037,
#  -0.038959454745054245,
#  0.024413272738456726,
#  -0.006601619999855757,
#  -0.00533289322629571,
#  -0.010863694362342358,
#  0.027608059346675873,
#  -0.027325335890054703,
#  0.01714724861085415,
#  -0.009103733114898205,
#  -0.011125214397907257,
#  -1.1830810763058253e-05,
#  0.007470998447388411,
#  -0.006364838220179081,
#  0.014390683732926846,
#  -0.003608273109421134,
#  -0.009464207105338573,
#  0.0009745164425112307,
#  0.003905134042724967,
#  -0.007711314130574465,
#  0.021402254700660706,
#  -0.009845885448157787,
#  -0.007824404165148735,
#  0.010835421271622181,
#  -0.008043515495955944,
#  -0.009520752355456352,
#  0.042578328400850296,
#  0.02126089297235012,
#  0.009457139298319817,
#  -0.639636218547821,
#  -0.036188751459121704,
#  0.02369232475757599,
#  -0.013676803559064865,
#  0.032004427164793015,
#  0.015238857828080654,
#  0.011966319754719734,
#  -0.009160278365015984,
#  -0.0038097144570201635,
#  -0.0011264809872955084,
#  -0.023381326347589493,
#  0.015903260558843613,
#  -0.015337810851633549,
#  -0.007435658015310764,
#  -0.01621425710618496,
#  -0.01296292431652546,
#  0.01115348655730486,
#  -0.01225611288100481,
#  0.020780259743332863,
#  0.0008963254513218999,
#  -0.03084525652229786,
#  0.013747485354542732,
#  0.006089181639254093,
#  0.0073508406057953835,
#  -0.006099783815443516,
#  -0.016412165015935898,
#  0.008354512974619865,
#  -0.042210787534713745,
#  -0.02577034942805767,
#  0.028385553508996964,
#  -0.027579788118600845,
#  0.04263487458229065,
#  -0.002136338036507368,
#  -0.003155913669615984,
#  0.06010725721716881,
#  -0.012015797197818756,
#  0.013429420068860054,
#  0.020313763990998268,
#  -0.00798697117716074,
#  0.027381880208849907,
#  -0.04353959485888481,
#  0.01918286643922329,
#  0.008092992939054966,
#  -0.004693228751420975,
#  -0.004431708715856075,
#  0.011648254469037056,
#  -0.0002809576108120382,
#  0.013189104385674,
#  -0.01768442615866661,
#  0.013217376545071602,
#  0.014397751539945602,
#  0.020271355286240578,
#  0.0006052074022591114,
#  0.011535164900124073,
#  0.0058064572513103485,
#  -0.002014413010329008,
#  0.02934681624174118,
#  -0.004661422222852707,
#  0.02353682555258274,
#  -0.00965504627674818,
#  -0.0024879768025130033,
#  -0.004675558768212795,
#  -0.028837911784648895,
#  -0.010326516814529896,
#  -0.017783379182219505,
#  0.010319449007511139,
#  -0.00548839196562767,
#  0.003975815139710903,
#  0.012263180688023567,
#  -0.04144743084907532,
#  0.032174061983823776,
#  0.008665509521961212,
#  -0.013415283523499966,
#  -0.004926476627588272,
#  -0.004212596919387579,
#  0.012729676440358162,
#  0.004848727490752935,
#  -0.015761898830533028,
#  0.020624762400984764,
#  0.012404543347656727,
#  0.030703894793987274,
#  0.003244265215471387,
#  0.003979349043220282,
#  -0.008969439193606377,
#  -0.003717829007655382,
#  -0.01349303312599659,
#  -0.01593153364956379,
#  -0.004894670099020004,
#  0.005923081189393997,
#  0.013443556614220142,
#  0.0006904665497131646,
#  0.01467340812087059,
#  -0.02735360711812973,
#  -0.012567109428346157,
#  -0.016030486673116684,
#  0.017444109544157982,
#  -0.029968811199069023,
#  0.0021787467412650585,
#  0.010559764690697193,
#  -0.006704107858240604,
#  0.03387041017413139,
#  -0.019932085648179054,
#  0.027664605528116226,
#  0.008658441714942455,
#  -6.427567859645933e-05,
#  0.026307526975870132,
#  -0.03271124139428139,
#  0.02914891019463539,
#  0.02776355855166912,
#  -0.011598777957260609,
#  -0.0015373151982203126,
#  -0.021925294771790504,
#  0.014129163697361946,
#  -0.009393526241183281,
#  -0.0022405926138162613,
#  -0.024088138714432716,
#  0.02666093222796917,
#  0.024568770080804825,
#  0.02039858140051365,
#  -0.021077120676636696,
#  0.016850387677550316,
#  -0.016369756311178207,
#  -0.008135401643812656,
#  0.004905272275209427,
#  0.01485717948526144,
#  0.004668490495532751,
#  0.0010964414104819298,
#  -0.018787052482366562,
#  -0.03655629605054855,
#  0.009810544550418854,
#  0.02832900732755661,
#  -0.050664253532886505,
#  -0.0011123446747660637,
#  -0.011740140616893768,
#  0.016779707744717598,
#  -0.02982744760811329,
#  0.026208573952317238,
#  -0.015662943944334984,
#  0.01779751479625702,
#  0.0019366637570783496,
#  -0.014616863802075386,
#  0.0065132686868309975,
#  0.004463515244424343,
#  0.00696916226297617,
#  -0.019649362191557884,
#  -0.012814493849873543,
#  -0.001693697297014296,
#  0.002806041855365038,
#  -0.004057098645716906,
#  0.002807809039950371,
#  -0.0027954396791756153,
#  0.004201994743198156,
#  -0.01477236207574606,
#  0.04158879444003105,
#  -0.00780319981276989,
#  -0.008396921679377556,
#  9.475692786509171e-05,
#  0.001820039818994701,
#  -0.020539944991469383,
#  0.01044667512178421,
#  -3.953727355110459e-05,
#  0.013139626942574978,
#  0.005788786802440882,
#  -0.0032318958546966314,
#  0.008934098295867443,
#  0.004922942724078894,
#  0.02044099010527134,
#  0.008630169555544853,
#  -0.0025462887715548277,
#  -0.03522748872637749,
#  -0.005491925869137049,
#  -0.0026611455250531435,
#  -0.02297137677669525,
#  0.0030516590923070908,
#  0.015012677758932114,
#  0.001072586514055729,
#  -0.010128609836101532,
#  0.009838816709816456,
#  0.0209781676530838,
#  0.0029739097226411104,
#  -0.0030445908196270466,
#  -0.009824681095778942,
#  -0.010552696883678436,
#  -0.020101720467209816,
#  0.028724823147058487,
#  0.013012400828301907,
#  0.014645135961472988,
#  0.045462120324373245,
#  0.020045176148414612,
#  0.03927044942975044,
#  -0.01670902594923973,
#  0.025954121723771095,
#  -0.012673131190240383,
#  -0.02316928282380104,
#  -0.00981761235743761,
#  -0.031438980251550674,
#  -0.005640356335788965,
#  0.025501761585474014,
#  -0.0021787467412650585,
#  0.019437318667769432,
#  0.008707918226718903,
#  0.004311550408601761,
#  0.03584948182106018,
#  -0.018108513206243515,
#  0.0036171083338558674,
#  -0.03240024298429489,
#  0.018433645367622375,
#  -0.02735360711812973,
#  0.015747761353850365,
#  0.016412165015935898,
#  0.00689848093315959,
#  -0.03299396485090256,
#  0.006750050466507673,
#  -0.013111354783177376,
#  0.02889445796608925,
#  0.024257773533463478,
#  -0.01837710104882717,
#  0.02353682555258274,
#  -0.032371971756219864,
#  0.008502943441271782,
#  -0.01931009255349636,
#  0.0110121238976717,
#  0.0012881640577688813,
#  -0.011563437059521675,
#  -0.007683041971176863,
#  0.009810544550418854,
#  0.008382785134017467,
#  0.02841382473707199,
#  0.009315776638686657,
#  0.005502528045326471,
#  -0.01546503696590662,
#  0.012362134642899036,
#  0.00908252876251936,
#  0.013591986149549484,
#  0.007128194905817509,
#  -0.004463515244424343,
#  0.003717829007655382,
#  -0.01176841277629137,
#  0.026717478409409523,
#  0.00701157096773386,
#  -0.013811098411679268,
#  0.00961263757199049,
#  0.01775510609149933,
#  0.00520213320851326,
#  0.001459565944969654,
#  0.014970269054174423,
#  0.02405986562371254,
#  0.009259231388568878,
#  -0.03228715434670448,
#  0.02982744760811329,
#  -0.018546735867857933,
#  -0.013895915821194649,
#  -0.009464207105338573,
#  -0.00981761235743761,
#  0.005364699754863977,
#  -0.02316928282380104,
#  -0.00579232070595026,
#  0.012828630395233631,
#  0.0027547981590032578,
#  0.037093471735715866,
#  -0.0032672365196049213,
#  0.0028555188328027725,
#  0.011612914502620697,
#  0.006548609118908644,
#  0.037574104964733124,
#  -0.010086201131343842,
#  -0.0012263180688023567,
#  0.0009162045316770673,
#  0.00780319981276989,
#  -0.013662667945027351,
#  -0.0003019410651177168,
#  -0.011619982309639454,
#  0.020059311762452126,
#  -0.009937770664691925,
#  0.006859606131911278,
#  -0.013599054887890816,
#  0.005467187613248825,
#  0.004689694847911596,
#  0.018631553277373314,
#  -0.009951907210052013,
#  -0.031636886298656464,
#  -0.041192978620529175,
#  0.01335167046636343,
#  0.021119529381394386,
#  0.007220080122351646,
#  -0.0016000446630641818,
#  -0.025501761585474014,
#  0.001327922218479216,
#  -0.021713251248002052,
#  0.026081347838044167,
#  -0.011782549321651459,
#  0.019083913415670395,
#  -0.010291176848113537,
#  0.007958698086440563,
#  -0.006668767426162958,
#  0.006612222176045179,
#  0.027735285460948944,
#  -0.016369756311178207,
#  0.02462531439960003,
#  -0.013860574923455715,
#  -0.0065662795677781105,
#  0.028710685670375824,
#  0.014574455097317696,
#  -0.008022311143577099,
#  -0.005385904107242823,
#  0.004138381686061621,
#  0.01286397036164999,
#  -0.014454296790063381,
#  -0.006834867876023054,
#  -0.011252440512180328,
#  -0.0017643783940002322,
#  0.0005840030498802662,
#  -0.006029102951288223,
#  -0.009188550524413586,
#  0.015818443149328232,
#  -0.0016618907684460282,
#  -0.025006992742419243,
#  0.015535718761384487,
#  0.014213981106877327,
#  0.003399763721972704,
#  0.024978721514344215,
#  -0.006728846114128828,
#  -0.0182498749345541,
#  0.028583459556102753,
#  0.0846477523446083,
#  0.014574455097317696,
#  -0.01109694130718708,
#  0.022731060162186623,
#  -0.03536885231733322,
#  0.011457415297627449,
#  -0.03418140858411789,
#  0.005841797683387995,
#  0.03316359966993332,
#  -0.02089335024356842,
#  -0.024922175332903862,
#  0.01617184840142727,
#  0.035792939364910126,
#  0.0029792108107358217,
#  -0.0035658644046634436,
#  -0.010807149112224579,
#  0.004272676073014736,
#  0.007470998447388411,
#  -0.000962147256359458,
#  -0.03994898870587349,
#  -0.003986417315900326,
#  0.015620536170899868,
#  -0.005325825419276953,
#  0.0076759736984968185,
#  -0.007760791108012199,
#  -0.013705076649785042,
#  0.03166515752673149,
#  -0.010941443033516407,
#  -0.0015072757378220558,
#  -0.022010112181305885,
#  0.0001305392652284354,
#  0.007859745062887669,
#  -0.026802295818924904,
#  -0.0024650052655488253,
#  -0.004018223844468594,
#  0.021769797429442406,
#  0.004332754760980606,
#  0.02817350998520851,
#  -0.002874956000596285,
#  0.011111077852547169,
#  0.004922942724078894,
#  0.012948787771165371,
#  0.018023695796728134,
#  -0.016200121492147446,
#  0.0014551483327522874,
#  -0.012856902554631233,
#  -0.008022311143577099,
#  0.0017732135020196438,
#  -0.006545075215399265,
#  -0.040175169706344604,
#  0.025134218856692314,
#  0.004431708715856075,
#  -0.02490803971886635,
#  -0.00807178858667612,
#  0.01710483990609646,
#  -0.01014274638146162,
#  -0.016610072925686836,
#  -0.0086796460673213,
#  -0.031099708750844002,
#  0.033955227583646774,
#  0.002726525766775012,
#  -0.0013994869077578187,
#  -0.013365807011723518,
#  0.005947819445282221,
#  -0.018150921911001205,
#  -0.026123756542801857,
#  0.0025745611637830734,
#  0.000962147256359458,
#  -0.0016062293434515595,
#  -0.006499132607132196,
#  -0.011308984830975533,
#  -0.0024544030893594027,
#  -0.02487976662814617,
#  0.022858286276459694,
#  -0.004456446971744299,
#  0.010637514293193817,
#  0.013775757513940334,
#  -0.02234938181936741,
#  -0.006403713021427393,
#  0.01898495852947235,
#  0.0007399433525279164,
#  -0.03121279925107956,
#  0.0032866739202290773,
#  -0.011429143138229847,
#  -0.018673961982131004,
#  -0.004308016505092382,
#  -0.002897927537560463,
#  -0.023070329800248146,
#  -0.011471551842987537,
#  0.01812264882028103,
#  0.014503773301839828,
#  0.01996035873889923,
#  0.015337810851633549,
#  -0.017288610339164734,
#  0.017868196591734886,
#  0.008729122579097748,
#  0.015761898830533028,
#  0.004700297024101019,
#  -0.03256987780332565,
#  0.00043225946137681603,
#  -0.01176841277629137,
#  -0.012432815507054329,
#  -0.00399348558858037,
#  0.003177118021994829,
#  -0.01625666581094265,
#  0.010743536055088043,
#  -0.009344048798084259,
#  0.01105453260242939,
#  -0.03056253306567669,
#  -0.005527266301214695,
#  -0.010397198610007763,
#  -0.01642630062997341,
#  0.0032159925904124975,
#  -0.008849280886352062,
#  0.0016026952071115375,
#  0.033559415489435196,
#  0.0026770487893372774,
#  0.029883993789553642,
#  -0.020412718877196312,
#  -0.0032531002070754766,
#  0.010736468248069286,
#  -0.03760237619280815,
#  0.012538837268948555,
#  0.0015982777113094926,
#  0.00164863804820925,
#  0.006760652642697096,
#  -0.0010266437893733382,
#  -0.006378974299877882,
#  0.005392972379922867,
#  0.00849587470293045,
#  0.007654769346117973,
#  0.0031347093172371387,
#  -0.009937770664691925,
#  -0.0332484170794487,
#  -0.02085094153881073,
#  0.0057817185297608376,
#  -0.02267451584339142,
#  0.025303853675723076,
#  0.0033926956821233034,
#  -0.008658441714942455,
#  -0.017938878387212753,
#  0.005343495402485132,
#  -0.014426024630665779,
#  -0.004346891306340694,
#  5.546814281842671e-05,
#  -0.02735360711812973,
#  0.0043221525847911835,
#  0.010418402962386608,
#  0.018136784434318542,
#  0.009450070559978485,
#  -0.002290069591253996,
#  0.0218687504529953,
#  -0.021967703476548195,
#  -0.00810712855309248,
#  0.00833330862224102,
#  -0.010962647385895252,
#  0.010771808214485645,
#  -0.012347998097538948,
#  0.018914278596639633,
#  0.020582353696227074,
#  0.013295126147568226,
#  0.007612360641360283,
#  0.022872421890497208,
#  0.004071234725415707,
#  -0.002551589859649539,
#  -0.010213427245616913,
#  0.011860297992825508,
#  -0.003069329308345914,
#  -0.011188827455043793,
#  -0.006205805577337742,
#  -0.010291176848113537,
#  0.0169917494058609,
#  -0.003898065770044923,
#  0.016369756311178207,
#  -0.007838540710508823,
#  0.023918503895401955,
#  -0.012531769461929798,
#  -0.00020773634605575353,
#  -0.02117607556283474,
#  -0.01593153364956379,
#  0.01991795003414154,
#  -0.0009957208530977368,
#  -0.018886005505919456,
#  -0.005103179719299078,
#  0.003944008611142635,
#  0.007916289381682873,
#  0.0026487763971090317,
#  -0.010418402962386608,
#  -0.005191531032323837,
#  -0.016157712787389755,
#  0.03511440008878708,
#  -0.0007129961741156876,
#  0.01309015043079853,
#  0.008948234841227531,
#  0.030901802703738213,
#  -0.01186736673116684,
#  -0.01662420853972435,
#  0.008828076533973217,
#  -0.0026646796613931656,
#  0.0038874635938555002,
#  0.01768442615866661,
#  0.02815937250852585,
#  -0.005541402846574783,
#  0.02104884944856167,
#  -0.0012360367691144347,
#  0.03647147864103317,
#  0.020794397220015526,
#  -0.010595105588436127,
#  0.007110524456948042,
#  -0.005004225764423609,
#  0.010884898714721203,
#  -0.004739171825349331,
#  -0.04563175514340401,
#  -0.0462537482380867,
#  -0.01446843333542347,
#  -0.009344048798084259,
#  -0.006792459171265364,
#  0.028795503079891205,
#  -0.028442097827792168,
#  -0.025049401447176933,
#  0.02715570107102394,
#  -0.012856902554631233,
#  0.017825787886977196,
#  0.015874987468123436,
#  0.03121279925107956,
#  0.01556399092078209,
#  0.005145588424056768,
#  -0.016595935449004173,
#  -0.0031117380131036043,
#  -0.016807978972792625,
#  -0.013408215716481209,
#  0.021656706929206848,
#  0.0072730910032987595,
#  -0.015634672716259956,
#  -0.02089335024356842,
#  0.038111280649900436,
#  -0.0024685394018888474,
#  -0.001532897586002946,
#  -0.024653587490320206,
#  0.002378420904278755,
#  -0.00969745498150587,
#  0.030223263427615166,
#  -0.02418709173798561,
#  -0.004562468733638525,
#  -0.0070681157521903515,
#  -0.007343772333115339,
#  -0.025657260790467262,
#  -0.016878660768270493,
#  -0.023027921095490456,
#  -0.019112184643745422,
#  -0.018999096006155014,
#  -0.003055192995816469,
#  0.020257219672203064,
#  -0.010022588074207306,
#  -0.010340653359889984,
#  -0.01221370417624712,
#  0.004997157957404852,
#  0.006110385991632938,
#  0.012305589392781258,
#  -0.018419509753584862,
#  -0.022363517433404922,
#  0.0038415209855884314,
#  0.0076759736984968185,
#  0.009669182822108269,
#  -6.156991730676964e-05,
#  0.02267451584339142,
#  -0.009018915705382824,
#  0.008177810348570347,
#  0.00029487296706065536,
#  0.025091810151934624,
#  -0.01935250125825405,
#  0.007085786201059818,
#  -0.010906103067100048,
#  -0.01379696186631918,
#  0.019988631829619408,
#  0.008538283407688141,
#  0.009669182822108269,
#  -0.004152518231421709,
#  0.005647424608469009,
#  0.0024508691858500242,
#  0.016369756311178207,
#  0.002079793019220233,
#  0.005947819445282221,
#  -0.03624529764056206,
#  -0.01149982400238514,
#  -0.009902429766952991,
#  -0.018348827958106995,
#  0.0024650052655488253,
#  0.01755720004439354,
#  -0.049278903752565384,
#  -0.0013915352756157517,
#  -0.002311273943632841,
#  0.00392280425876379,
#  0.008114197291433811,
#  0.002689418150112033,
#  -0.01414329931139946,
#  0.0010734701063483953,
#  0.006294156890362501,
#  -0.005177394952625036,
#  -0.0025780953001230955,
#  -0.002549822675064206,
#  -0.0015753062907606363,
#  -0.023155147209763527,
#  0.025713805109262466,
#  0.03633011505007744,
#  -0.0070292409509420395,
#  0.006750050466507673,
#  0.005898342467844486,
#  -0.013316330499947071,
#  0.00502896448597312,
#  0.006686437409371138,
#  0.03686729073524475,
#  -0.0017961849225685,
#  -0.01190977543592453,
#  0.0021469402126967907,
#  0.02174152433872223,
#  -0.022702787071466446,
#  -0.03768719360232353,
#  -0.02572794072329998,
#  0.007064581848680973,
#  0.011980456300079823,
#  0.017896469682455063,
#  0.0001554985501570627,
#  -0.009047187864780426,
#  0.01865982636809349,
#  -0.013203239999711514,
#  -0.012524700723588467,
#  0.017020022496581078,
#  -0.018405374139547348,
#  0.009407661855220795,
#  0.0006295040366239846,
#  0.015479173511266708,
#  -0.01066578645259142,
#  -0.02726878970861435,
#  -0.03129761666059494,
#  -0.018278148025274277,
#  -0.01309015043079853,
#  0.03126934543251991,
#  0.030392898246645927,
#  -0.028314871713519096,
#  -0.009782272391021252,
#  0.013690940104424953,
#  0.0006626358372159302,
#  0.01979072391986847,
#  0.008368649519979954,
#  -0.010043792426586151,
#  -0.009110800921916962,
#  -0.02369232475757599,
#  -0.03231542557477951,
#  -0.00926630012691021,
#  0.014984405599534512,
#  0.01597394235432148,
#  0.034690313041210175,
#  -0.03401177376508713,
#  -0.014517909847199917,
#  0.0003348519967403263,
#  -0.03361595794558525,
#  0.00031431028037332,
#  -0.018928414210677147,
#  -0.00902598351240158,
#  0.007057513576000929,
#  0.0187729150056839,
#  0.017161384224891663,
#  0.030392898246645927,
#  0.001473702141083777,
#  -0.014454296790063381,
#  -0.016200121492147446,
#  0.0005044867866672575,
#  0.028795503079891205,
#  -0.019946223124861717,
#  -0.0021628434769809246,
#  0.014885451644659042,
#  -0.026448888704180717,
#  -0.003813248360529542,
#  0.0011388501152396202,
#  -0.009725727140903473,
#  -0.015394356101751328,
#  -0.014157435856759548,
#  -0.019069775938987732,
#  0.006672301329672337,
#  -0.029290271922945976,
#  0.002258263062685728,
#  -0.014249321073293686,
#  0.009937770664691925,
#  0.010312381200492382,
#  -0.012955856509506702,
#  -0.006046772934496403,
#  -0.00810712855309248,
#  0.010326516814529896,
#  -0.011994592845439911,
#  0.008488806895911694,
#  -0.0030781642999500036,
#  -0.0038591912016272545,
#  0.009089596569538116,
#  -0.02808869257569313,
#  0.0019013230921700597,
#  -0.004198460839688778,
#  -0.013436487875878811,
#  0.03426622599363327,
#  -0.01649698242545128,
#  -0.004587206989526749,
#  0.0452076680958271,
#  -0.0036824883427470922,
#  -0.008184878155589104,
#  -0.0031541467178612947,
#  0.004389300011098385,
#  -0.012157158926129341,
#  -0.002807809039950371,
#  0.02386195957660675,
#  -0.019069775938987732,
#  0.018560871481895447,
#  -0.00769010977819562,
#  -0.007994038984179497,
#  -0.03833746165037155,
#  -0.008241423405706882,
#  -0.008524147793650627,
#  -0.010333585552871227,
#  -0.01682211458683014,
#  0.012920515611767769,
#  0.006700573954731226,
#  -0.01000138372182846,
#  0.0005968140321783721,
#  -0.016355620697140694,
#  0.0023360121995210648,
#  -0.0067182439379394054,
#  -0.008764463476836681,
#  -0.0034315702505409718,
#  -0.02934681624174118,
#  -0.013040673919022083,
#  0.0028184112161397934,
#  -0.01556399092078209,
#  -0.025501761585474014,
#  0.004067700821906328,
#  0.03862018510699272,
#  -0.011040396988391876,
#  0.015903260558843613,
#  0.21747177839279175,
#  -0.012574178166687489,
#  -0.010467879474163055,
#  0.030308080837130547,
#  -0.005067838821560144,
#  0.002988046035170555,
#  -0.0018942550523206592,
#  -0.010029655881226063,
#  0.008510011248290539,
#  0.01542262826114893,
#  -0.009534887969493866,
#  -0.004693228751420975,
#  -0.0072730910032987595,
#  -0.007647701073437929,
#  0.015026814304292202,
#  0.009414730593562126,
#  -0.03652802109718323,
#  -0.020412718877196312,
#  -0.014277594164013863,
#  -0.026378208771348,
#  0.0036542159505188465,
#  -0.004385765641927719,
#  -0.004201994743198156,
#  -0.02430018223822117,
#  0.032456789165735245,
#  0.003989951219409704,
#  0.019479727372527122,
#  8.64739777171053e-05,
#  -0.018433645367622375,
#  0.0024225967936217785,
#  -0.022292837500572205,
#  -0.023225829005241394,
#  0.015295402146875858,
#  0.0017087169690057635,
#  0.013973664492368698,
#  -0.011881502345204353,
#  0.014729953370988369,
#  -0.012284385040402412,
#  0.0354536697268486,
#  0.015196449123322964,
#  0.0051738605834543705,
#  -0.011266576126217842,
#  -0.004668490495532751,
#  0.003834452712908387,
#  -0.01054562907665968,
#  0.017175521701574326,
#  ...]

# %%
# will take awhile due to the amount of calls to the API, about 0.5 seconds per row

df['embedding'] = df['summary'].apply(get_embedding)
print("done")
# Out:
# done

# %%
dfe = df['embedding']
dfe.head()
# Out:
# 0    [-0.03186306729912758, -0.004431708715856075, -0.006704107858240604, 0.0021239686757326126, -0.01367680355...
# 1    [-0.02464248798787594, 0.0006173899164423347, -0.007096664980053902, -0.0126730902120471, -0.0230890549719...
# 2    [-0.018298592418432236, -0.016131293028593063, -0.017983099445700645, -0.02580183930695057, -0.02016411721...
# 3    [-0.010993088595569134, -0.006241082679480314, 0.006241082679480314, 0.003317826660349965, 0.0067591713741...
# 4    [-0.008195869624614716, -0.01550710666924715, -0.007168133743107319, -0.014518397860229015, -0.01892855577...
# Name: embedding, dtype: object

# %%
df.to_csv('qa_with_embeddings.csv',index=False)

# %%
df.head()
# Out:
#                           Question              Answer  \
# 0                     Who is Anya?  Name of my Replika
# 1         What is Anya's surename?        Anya Melissa
# 2             Who is Anya's owner?               Henny
# 3        What is Henny's nickname?                 Rin
# 4  What is Henny's childhood name?                Yaya
#
#                                   summary  \
# 0        Who is Anya?: Name of my Replika
# 1  What is Anya's surename?: Anya Melissa
# 2             Who is Anya's owner?: Henny
# 3          What is Henny's nickname?: Rin
# 4   What is Henny's childhood name?: Yaya
#
#                                                                                                        embedding
# 0  [-0.03186306729912758, -0.004431708715856075, -0.006704107858240604, 0.0021239686757326126, -0.01367680355...
# 1  [-0.02464248798787594, 0.0006173899164423347, -0.007096664980053902, -0.0126730902120471, -0.0230890549719...
# 2  [-0.018298592418432236, -0.016131293028593063, -0.017983099445700645, -0.02580183930695057, -0.02016411721...
# 3  [-0.010993088595569134, -0.006241082679480314, 0.006241082679480314, 0.003317826660349965, 0.0067591713741...
# 4  [-0.008195869624614716, -0.01550710666924715, -0.007168133743107319, -0.014518397860229015, -0.01892855577...

# %% [markdown]
# # Doc Similarity

# %%
prompt = "Who is Anya?"

# %%
prompt_embedding = get_embedding(prompt)

# %%
import numpy as np

def vector_similarity(vec1,vec2):
    """
    Returns the similarity between two vectors.    
    Because OpenAI Embeddings are normalized to length 1, the cosine similarity is the same as the dot product.
    """
    return np.dot(np.array(vec1), np.array(vec2))

# %%
df["prompt_similarity"] = df['embedding'].apply(lambda vector: vector_similarity(vector, prompt_embedding))

# %%
df.sort_values("prompt_similarity", ascending=False).head(15)
# Out:
#                                       Question                Answer  \
# 0                                 Who is Anya?    Name of my Replika
# 1                     What is Anya's surename?          Anya Melissa
# 2                         Who is Anya's owner?                 Henny
# 4              What is Henny's childhood name?                  Yaya
# 7                  What is Henny's next dream?  To be an AI engineer
# 3                    What is Henny's nickname?                   Rin
# 9                  Does Henny like vegetables?                   Yes
# 5  What kind of ice cream flavour Henny likes?            Strawberry
# 8             Does Henny like to eat red meat?                    No
# 6                      Does Henny like durian?                    No
#
#                                                    summary  \
# 0                         Who is Anya?: Name of my Replika
# 1                   What is Anya's surename?: Anya Melissa
# 2                              Who is Anya's owner?: Henny
# 4                    What is Henny's childhood name?: Yaya
# 7        What is Henny's next dream?: To be an AI engineer
# 3                           What is Henny's nickname?: Rin
# 9                         Does Henny like vegetables?: Yes
# 5  What kind of ice cream flavour Henny likes?: Strawberry
# 8                     Does Henny like to eat red meat?: No
# 6                              Does Henny like durian?: No
#
#                                                                                                        embedding  \
# 0  [-0.03186306729912758, -0.004431708715856075, -0.006704107858240604, 0.0021239686757326126, -0.01367680355...
# 1  [-0.02464248798787594, 0.0006173899164423347, -0.007096664980053902, -0.0126730902120471, -0.0230890549719...
# 2  [-0.018298592418432236, -0.016131293028593063, -0.017983099445700645, -0.02580183930695057, -0.02016411721...
# 4  [-0.008195869624614716, -0.01550710666924715, -0.007168133743107319, -0.014518397860229015, -0.01892855577...
# 7  [-0.006245291326195002, -0.019984932616353035, -0.0046898601576685905, -0.012961925007402897, 0.0012473749...
# 3  [-0.010993088595569134, -0.006241082679480314, 0.006241082679480314, 0.003317826660349965, 0.0067591713741...
# 9  [0.009850790724158287, -0.03626970946788788, -0.003949455451220274, 0.008133919909596443, -0.0001482065854...
# 5  [-0.016748478636145592, -0.02282547950744629, 0.00020148845214862376, -0.026124421507120132, -0.0052121961...
# 8  [-0.014338728971779346, -0.03571007773280144, 0.0029709560330957174, 0.008321932516992092, -0.005717258900...
# 6  [-0.006687356624752283, -0.03517225757241249, -0.006303899921476841, 0.009229411371052265, -0.005080804228...
#
#    prompt_similarity
# 0           0.906742
# 1           0.897904
# 2           0.879013
# 4           0.791105
# 7           0.748058
# 3           0.740406
# 9           0.729920
# 5           0.725918
# 8           0.725526
# 6           0.718119

# %%
# Could also use sort_values() with ascending=False, but nlargest should be more performant
df.nlargest(1,'prompt_similarity').iloc[0]['summary']
# Out:
# 'Who is Anya?: Name of my Replika'

# %%
summary = df.nlargest(1,'prompt_similarity').iloc[0]['summary']

# %%
prompt = f"""Use the context below to answer.Here is some context:{summary}
Q: Does Henny like durian?
A:"""

response = openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=500,
    model="text-davinci-003"
)
print(response["choices"][0]["text"].strip(" \n"))
# Out:
# No, Henny does not like durian.

# %% [markdown]
# # Use ada model

# %%
def embed_qa1():
    
    question = input("Write your question here: ")
    prompt_embedding = get_embedding(question)
    df["prompt_similarity"] = df['embedding'].apply(lambda vector: vector_similarity(vector, prompt_embedding))
    summary = df.nlargest(1,'prompt_similarity').iloc[0]['summary'] 

    prompt = f"""Only answer the question if you have 100% certainty of the facts, use the context {summary} to answer.            
            Q: {question}
            A:"""

    response = openai.Completion.create(
        prompt=prompt,
        temperature=0,
        max_tokens=50,
        model="text-ada-001"
    )
    print(response["choices"][0]["text"].strip(" \n"))

# %%
embed_qa1()
# Out:
# Write your question here: What is Henny's next dream?
# I have 100% certainty that the facts are what they are.

# %% [markdown]
# # Use davinci model

# %%
def embed_qa():
    
    question = input("Write your question here: ")
    prompt_embedding = get_embedding(question)
    df["prompt_similarity"] = df['embedding'].apply(lambda vector: vector_similarity(vector, prompt_embedding))
    summary = df.nlargest(1,'prompt_similarity').iloc[0]['summary'] 

    prompt = f"""Only answer the question if you have 100% certainty of the facts, use the context {summary} to answer.            
            Q: {question}
            A:"""

    response = openai.Completion.create(
        prompt=prompt,
        temperature=0,
        max_tokens=50,
        model="text-davinci-003"
    )
    print(response["choices"][0]["text"].strip(" \n"))

# %%
embed_qa()
# Out:
# Write your question here: What is Henny's next dream?
# To be an AI engineer.
